# %% [markdown]
# ## Pandas Lab 1
# For this lab, you will need to read in the provided FASTA file and generate a DataFrame containing the following information for each sequence record:
# 1. Sequence Length
# 2. GC content
# 3. Begins with start codon?
# 4. Ends in stop codon?
# 5. Complete frame? (Meaning is the length a multiple of 3?)
#
# The row index should be the sequence label, and columns should be labeled with descriptions of these 5 criteria I've given you. Be mindful of the datatype you choose for description 3-5.

# %%
#%pip install biopython
#%pip install pandas

# %% [markdown]
# ### __Imports

# %%
from Bio import SeqIO
import pandas as pd
#supplied codon/aa dictionary
aa_dict = {'M':['ATG'], 'F':['TTT', 'TTC'], 'L':['TTA', 'TTG', 'CTT', 'CTC', 'CTA', 'CTG'], 'C':['TGT', 'TGC'], 'Y':['TAC', 'TAT'], 'W':['TGG'], 'P':['CCT', 'CCC', 'CCA', 'CCG'], 'H':['CAT', 'CAC'],
'Q':['CAA', 'CAG'], 'R':['CGT', 'CGC', 'CGA', 'CGG', 'AGA', 'AGG'], 'I':['ATT', 'ATC', 'ATA'], 'T':['ACT', 'ACC', 'ACA', 'ACG'],
'N':['AAT', 'AAC'], 'K':['AAA', 'AAG'], 'S':['AGT', 'AGC', 'TCT', 'TCC', 'TCA', 'TCG'], 'V':['GTT', 'GTC', 'GTA', 'GTG'],
'A':['GCT', 'GCC', 'GCA', 'GCG'], 'D':['GAT', 'GAC'], 'E':['GAA', 'GAG'], 'G':['GGT', 'GGC', 'GGA', 'GGG'], '*':['TAA','TAG','TGA']}

# %% [markdown]
# ### __Functions

# %%
def codonchecker(stringy):
    if len(stringy)==3:
        for key,val in aa_dict.items():
            if str.upper(stringy) in val:
                return True
            else:
                return False
    else:
        return False

# %% [markdown]
# #### Delcare new Seq objects from parsing supplied FASTA file

# %%
fh = open("Mdomestica-pandasLab.fa","r")
newOBJs = SeqIO.to_dict(SeqIO.parse(fh,"fasta"))

# %%
#obj12= newOBJs["MD10G1276500"]
myDF = pd.DataFrame(newOBJs.items(),columns=["Label","Seq"])
myDF["SeqLen"]=0
myDF["GCcontent"]= 0.0000
myDF['startString3'] ="AAA"
myDF["startCodon"]=False
myDF["endString3"]="ZZZ"
myDF["stopCodon"]=False
myDF["compFrame"]=False
for indx in myDF.index:
        #L =len(myDF["Seq"][indx].seq)
        L=len(str(myDF.loc[indx,"Seq"].seq))
        myDF.at[indx,"SeqLen"]=L
        ctr = 0
        for i in str(myDF.loc[indx,"Seq"].seq):
            if i == "C" or i=="G":
                ctr+=1
        myDF.at[indx,"GCcontent"]=ctr/L
        myDF.at[indx,"startString3"]=str(myDF.loc[indx,"Seq"].seq[0:3])
        myDF.at[indx,"startCodon"]=codonchecker(str(myDF.loc[indx,"Seq"].seq)[0:3])
        myDF.at[indx,"endString3"]=str(myDF.loc[indx,"Seq"].seq)[L-3:L]
        myDF.at[indx,"stopCodon"]=codonchecker(str(myDF.loc[indx,"Seq"].seq)[L-3:L])
        if L%3 == 0:
            myDF.at[indx,"compFrame"]=True
        else:
            myDF.at[indx,"compFrame"]=False

# %%
myDF
# Out:
#              Label                                                Seq  SeqLen  \
# 0     MD10G1276500  (C, A, G, T, C, C, G, T, G, G, C, T, C, C, T, ...    2940
# 1     MD10G1110200  (A, T, G, G, C, G, T, C, T, C, T, C, T, C, C, ...    1731
# 2     MD10G1036500  (A, T, G, T, C, G, T, C, G, T, C, G, T, C, G, ...     468
# 3     MD10G1170700  (A, T, G, T, A, T, C, G, C, T, T, C, G, C, C, ...    1728
# 4     MD10G1250900  (A, T, G, G, A, A, G, T, G, T, A, T, G, G, G, ...    1278
# ...            ...                                                ...     ...
# 7491  MD14G1066400  (A, T, G, C, C, A, T, C, G, T, G, G, T, T, C, ...     423
# 7492  MD14G1225900  (A, T, G, G, C, T, T, C, C, C, C, T, A, A, C, ...     594
# 7493  MD14G1120900  (A, T, G, G, A, T, A, A, C, T, C, T, G, C, A, ...     939
# 7494  MD14G1057700  (A, T, G, G, A, A, G, C, T, A, T, C, A, C, T, ...     483
# 7495  MD14G1237500  (A, T, G, G, C, G, G, T, T, G, T, C, A, C, C, ...    3270
#
#       GCcontent startString3  startCodon endString3  stopCodon  compFrame
# 0      0.460544          CAG       False        TGA      False       True
# 1      0.464471          ATG        True        TAA      False       True
# 2      0.544872          ATG        True        TGA      False       True
# 3      0.446759          ATG        True        TAG      False       True
# 4      0.402973          ATG        True        TAA      False       True
# ...         ...          ...         ...        ...        ...        ...
# 7491   0.529551          ATG        True        TAA      False       True
# 7492   0.503367          ATG        True        TAA      False       True
# 7493   0.481363          ATG        True        TAG      False       True
# 7494   0.523810          ATG        True        TAG      False       True
# 7495   0.442202          ATG        True        TGA      False       True
#
# [7496 rows x 9 columns]
